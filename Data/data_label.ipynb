# %%
import json
import csv
import pandas as pd
df=pd.read_excel("/content/project-7-at-2022-12-23-14-07-3068d261 (1).xlsx")

# %%
df2=df[['text','label/0/text','label/0/labels/0']]

# %%
df2.columns=['text','word','label']

# %%
df2
# Out:
#                                                  text      word        label
# 0   وقبال,من خالص اعماق قلبى اتقدم بالتهانى لكل ال...      قبال  miss spelld
# 1                    الايطالة,وشكرا واسف علي الايطالة  الايطالة  miss spelld
# 2   وعرى,احب اقول لكل جزائرى يقول ان ميبشوفش على ا...       عرى   novel term
# 3   شاءاله,ماذا دهاكمالموضوع سمكةأفريللابد من التح...    شاءاله  miss spelld
# 4                                 والسلا,والسلا عليكم     السلا  miss spelld
# ..                                                ...       ...          ...
# 60  وأوعى,وأوعى تنسى محمد عامر ومختار مختار وهانى ...     وأوعى   novel term
# 61  ياناجى,عزومة فسيخ ولا منشطات لزوم تظبيط ماتش ا...    ياناجى  miss spelld
# 62  تظبيط,عزومة فسيخ ولا منشطات لزوم تظبيط ماتش ال...     تظبيط   novel term
# 63      الجامدة,ربنا يستر عليهم بعد الاكلة الجامدة دى   الجامدة   novel term
# 64                                  التسم,صباح التسم      التسم  miss spelld
#
# [65 rows x 3 columns]
